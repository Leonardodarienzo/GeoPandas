# %% [markdown]
# <a href="https://colab.research.google.com/github/Leonardodarienzo/GeoPandas/blob/main/Esercizio4(Geopandas).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# caricare il geodataframe delle piste ciclabili bike_ciclabili.zip

# %%
# !pip install geopandas

# %%
import geopandas

# %%
from google.colab import drive
drive.mount('/content/drive',force_remount=True)

# %%
pisteciclabili = geopandas.read_file("/content/drive/MyDrive/Colab Notebooks/bike_ciclabili")
pisteciclabili

# %%
# visualizzare il geodataframe

# %%
# !pip install contextily
import contextily

# %%
ax = pisteciclabili.plot()
contextily.add_basemap(ax)

# %%
# caricare il geodataframe dei quartieri ds964_nil_wm.zip

# %%
quartieridiMilano = geopandas.read_file("/content/drive/MyDrive/Colab Notebooks/ds964_nil_wm")
quartieridiMilano

# %%
# visualizza la mappa dei quartieri e delle piste ciclabili

# %%
ax = quartieridiMilano.plot()
contextily.add_basemap(ax)

# %%
quartieridiMilano.crs

# %%
quartieridiMilano3857 = quartieridiMilano.to_crs(epsg=3857)
quartieridiMilano3857

# %%
ax = quartieridiMilano3857.plot(figsize = (13,6),facecolor = 'none', edgecolor = 'black')
contextily.add_basemap(ax)

# %%
ax = pisteciclabili.plot()
contextily.add_basemap(ax)

# %%
pisteciclabili.crs

# %%
pisteciclabili3857 = pisteciclabili.to_crs(epsg=3857)
pisteciclabili3857

# %%
ax = pisteciclabili3857.plot(figsize = (13,6),facecolor = 'none', edgecolor = 'black')
contextily.add_basemap(ax)

# %%
# creare una geoserie con le informazioni sulla ciclabile di via Melchiorre Gioia e visualizzarla

# %%
Melchiorregioia = pisteciclabili[pisteciclabili.anagrafica.str.contains("VIA MELCHIORRE GIOIA")]
Melchiorregioia

# %%
# trovare tutti i quartieri attraversati da questa pista ciclabile

# %%
# visualizzare su una mappa la pista ciclabile e i quartieri attraversati (utilizzare i colori presenti nell'esempio)

# %%
# caricare il geodataframe delle fontanelle Fontanelle.zip

# %%
fontanelleMilano = geopandas.read_file("/content/drive/MyDrive/Colab Notebooks/Fontanelle")
fontanelleMilano

# %%
# visualizzare il geodataframe su una mappa

# %%
ax = fontanelleMilano.plot()
contextily.add_basemap(ax)

# %%
fontanelleMilano.crs

# %%
fontanelleMilano3857 = fontanelleMilano.to_crs(epsg=3857)
fontanelleMilano3857

# %%
ax = fontanelleMilano3857.plot(figsize = (13,6),facecolor = 'none', edgecolor = 'black')
contextily.add_basemap(ax)

# %%
# visualizzare su una mappa le fontanelle e i quartieri in cui si trovano.
# non visualizzare i quartieri in cui non ci sono fontanelle

# %%
# colorare i quartieri in modo proporzionale al numero di fontanelle presenti (giallo molte fontanelle, blu scuro poche fontanelle)
# non evidenziare i quartieri senza fontanelle

# %%
# visalizzare la mappa precedente facendo in modo che i quartieri con fontanelle siano colorati con gradazioni di rosso
# e quelli senza fontanelle con gradazioni di grigio
